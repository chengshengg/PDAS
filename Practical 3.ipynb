# %% [markdown]
# # Welcome to Programming for Data Analytics Practical 3 👏

# %% [markdown]
# ## There is a part of a Datacamp Course that you need to do! However, you do not need to submit a certificate.
# 🖥️ https://app.datacamp.com/learn/courses/intro-to-python-for-data-science
#
# ### Under introduction for Python, complete the 4th module labelled NumPy.

# %% [markdown]
# ![image-2.png](attachment:image-2.png)
# ![image.png](attachment:image.png)

# %% [markdown]
# ## You may only proceed to do the question(s) below only after doing the DataCamp assignment
#
# ## ⚠️ Please avoid using ChatGPT or GenAI for these questions. Independent work is crucial for your success on the end-of-semester test.
#
# ## Use the local Jupyter Notebook without GenAI tools for this practical.
#
# ### Below is a portion of the cheatsheet that will be given to you for your EST, the EST is a closed book exam and you can only refer to this cheatsheet, and use Jupyter Notebook.
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### Background: You have found some messy shopping data, do you think you can use it to have insights? Additionally, you have noted that someone was trying to find these insights using this python notebook. However, upon inspection, the notebook seems to be incompleted with errors. Fix the errors to find the insights.
#
# ## For all questions please try to fill in the blanks or complete the code in order to make the code run.
#
# **Below this data is stored in data_string. Please make sure you run it.**

# %%
data_string = "1,Clothing,Shoes,99,2007-2-28;2,Books,Magazine,8,2005-8-2;3,Books,Novel,21,2002-4-16;4,Clothing,Shoes,62,2001-7-9;5,Home & Kitchen,Cookware,107,2006-4-21;6,Sports & Outdoors,Fishing Rod,1000,2008-6-23;7,Electronics,Tablet,1219,2002-10-20;8,Home & Kitchen,Appliances,300,2002-4-8;9,Clothing,Jacket,88,2004-3-3;10,Clothing,Pants,79,2005-6-9;11,Clothing,Dress,12,2006-1-25;12,Sports & Outdoors,Bicycle,604,2005-6-27;13,Books,Magazine,26,2009-6-25;14,Home & Kitchen,Decor,319,2007-7-8;15,Books,Biography,44,2005-6-22;16,Sports & Outdoors,Hiking Boots,872,2002-4-19;17,Clothing,Shirt,45,2002-10-16;18,Books,Biography,19,2007-7-29;19,Home & Kitchen,Appliances,207,2002-7-8;20,Sports & Outdoors,Fishing Rod,766,2001-11-26;21,Home & Kitchen,Decor,340,2007-1-10;22,Home & Kitchen,Decor,482,2001-6-7;23,Home & Kitchen,Cookware,276,2004-11-5;24,Home & Kitchen,Cookware,215,2004-12-9;25,Books,Magazine,23,2007-10-22;26,Electronics,Smartphone,1791,2008-1-18;27,Clothing,Pants,86,2001-2-5;28,Home & Kitchen,Cookware,190,2006-9-15;29,Home & Kitchen,Cookware,334,2003-1-20;30,Electronics,Laptop,775,2007-9-16;31,Clothing,Jacket,19,2008-5-6;32,Electronics,Camera,1619,2002-12-9;33,Sports & Outdoors,Bicycle,904,2005-4-25;34,Books,Biography,31,2009-4-11;35,Books,Biography,50,2004-9-14;36,Electronics,Smartphone,1960,2009-4-28;37,Home & Kitchen,Decor,427,2001-2-30;38,Books,Textbook,40,2008-7-18;39,Home & Kitchen,Furniture,102,2003-9-22;40,Home & Kitchen,Furniture,185,2002-11-28;41,Books,Magazine,30,2001-3-22;42,Books,Biography,27,2004-1-17;43,Home & Kitchen,Appliances,55,2006-2-23;44,Electronics,Headphones,1520,2007-8-19;45,Home & Kitchen,Decor,491,2007-4-18;46,Sports & Outdoors,Hiking Boots,643,2006-5-12;47,Electronics,Tablet,1108,2005-9-7;48,Sports & Outdoors,Tent,198,2008-5-2;49,Books,Comic,45,2006-9-3;50,Sports & Outdoors,Hiking Boots,405,2001-3-11;51,Home & Kitchen,Appliances,368,2004-3-26;52,Home & Kitchen,Cookware,178,2006-6-28;53,Home & Kitchen,Utensils,133,2003-12-9;54,Electronics,Tablet,1251,2001-12-14;55
,762,2006-11-21;958,Home & Kitchen,Decor,362,2008-12-10;959,Books,Magazine,28,2006-1-16;960,Clothing,Shirt,15,2007-1-21;961,Home & Kitchen,Decor,273,2008-8-24;962,Electronics,Laptop,1907,2008-9-22;963,Home & Kitchen,Utensils,234,2001-4-6;964,Sports & Outdoors,Bicycle,330,2009-10-3;965,Clothing,Shoes,35,2001-3-26;966,Home & Kitchen,Appliances,40,2002-11-1;967,Electronics,Headphones,356,2009-8-6;968,Home & Kitchen,Cookware,93,2009-2-19;969,Sports & Outdoors,Hiking Boots,743,2009-4-16;970,Books,Magazine,39,2006-1-26;971,Sports & Outdoors,Hiking Boots,200,2005-7-2;972,Sports & Outdoors,Bicycle,437,2008-5-4;973,Home & Kitchen,Decor,489,2005-8-24;974,Sports & Outdoors,Sleeping Bag,504,2004-6-1;975,Home & Kitchen,Furniture,427,2006-12-27;976,Sports & Outdoors,Sleeping Bag,371,2001-6-30;977,Clothing,Dress,89,2001-9-20;978,Electronics,Tablet,910,2005-9-26;979,Clothing,Jacket,11,2002-2-23;980,Home & Kitchen,Utensils,63,2004-5-30;981,Sports & Outdoors,Sleeping Bag,446,2004-2-19;982,Books,Biography,29,2002-3-27;983,Home & Kitchen,Utensils,405,2002-10-29;984,Books,Magazine,19,2002-6-28;985,Home & Kitchen,Decor,333,2003-3-9;986,Sports & Outdoors,Fishing Rod,737,2003-11-18;987,Electronics,Smartphone,1544,2002-7-2;988,Electronics,Smartphone,772,2002-3-2;989,Sports & Outdoors,Sleeping Bag,615,2001-10-8;990,Electronics,Smartphone,303,2002-12-19;991,Electronics,Headphones,720,2008-1-1;992,Sports & Outdoors,Fishing Rod,770,2001-5-6;993,Home & Kitchen,Utensils,79,2003-11-26;994,Books,Biography,33,2002-1-13;995,Electronics,Camera,1202,2009-11-20;996,Books,Textbook,46,2009-4-28;997,Sports & Outdoors,Fishing Rod,670,2004-2-20;998,Books,Biography,6,2001-3-4;999,Books,Textbook,5,2003-10-16;1000,Clothing,Dress,86,2006-11-16"

# %% [markdown]
# ### Q1 How can you process this data string into a numpy array? Fill up the comments with code.
#
# This should be your expected output:
#
# ![image.png](attachment:image.png)

# %%
import numpy as np

#split according to ";"
rows = data_string.split(";")
# Split each row into elements
split_rows = [row.split(",") for row in rows]
# Convert the list of lists into a NumPy array
numpy_array = np.array(split_rows)
# Print the NumPy array
print(numpy_array)

# Print the NumPy shape
print(numpy_array.shape)
# Out:
# [['1' 'Clothing' 'Shoes' '99' '2007-2-28']
#  ['2' 'Books' 'Magazine' '8' '2005-8-2']
#  ['3' 'Books' 'Novel' '21' '2002-4-16']
#  ...
#  ['998' 'Books' 'Biography' '6' '2001-3-4']
#  ['999' 'Books' 'Textbook' '5' '2003-10-16']
#  ['1000' 'Clothing' 'Dress' '86' '2006-11-16']]
# (1000, 5)

# %% [markdown]
# ### Q2. It seems that the shape of the array has five columns, and their column names are: index, category, item, price, date.
#
# Complete the code below, using boolean indexing to find out the dates of items that are sold after 2008.
#
# Your sample output should be similar to:
#
# ![image.png](attachment:image.png)

# %%
indices = numpy_array[:,4] > "2008"
filtered_arr = numpy_array[indices]
print(filtered_arr)
# Out:
# [['6' 'Sports & Outdoors' 'Fishing Rod' '1000' '2008-6-23']
#  ['13' 'Books' 'Magazine' '26' '2009-6-25']
#  ['26' 'Electronics' 'Smartphone' '1791' '2008-1-18']
#  ...
#  ['991' 'Electronics' 'Headphones' '720' '2008-1-1']
#  ['995' 'Electronics' 'Camera' '1202' '2009-11-20']
#  ['996' 'Books' 'Textbook' '46' '2009-4-28']]

# %% [markdown]
# ### Q3. Complete the code below, using boolean indexing to the prices of items greater than 1900.
#
# Reminder - column names are: index, category, item, price, date.
# Your sample output should be similar to:
#
# ![image.png](attachment:image.png)

# %%
#write your code here
prices = numpy_array[:, 3].astype(int)

filtered_prices = prices[prices > 1900]

print(filtered_prices)
# Out:
# [1960 1941 1931 1962 1999 1905 1935 1931 1990 1966 1918 1973 1907]

# %% [markdown]
# ### Q4. Analyze the data to find out the frequency of each item. And you have to use np.array().max() to find out what is the most frequently bought item.
#
# Your output should look like this:
#
# ![image.png](attachment:image.png)

# %%
#fill up your code! You may use a dictionary
items = numpy_array[:, 2]

frequency = {}

for item in items:
    if item in frequency:
        frequency[item] += 1
    else:
        frequency[item] = 1

print(frequency)

counts = np.array(list(frequency.values()))
max_count = counts.max()

for key, value in frequency.items():
    if value == max_count:
        print("Most frequently bought item:", key)

# %% [markdown]
# ### Q5. Finally, apply four different NumPy array mathematical operations to analyze the data and determine which category would be the best to sell if you were to take over the operations of the sales business (refer to the cheatsheet).
#
# E.g. Mean Calculation (np.mean) – Find the average sales per category to determine which one has the highest consistent revenue.
#
# Use markdown to explain why you chose these different NumPy Array operations

# %%
##Feel free to write as much code and explain in comments and markdown
prices = numpy_array[:, 3].astype(int)
categories = numpy_array[:, 1]

# Mean price
mean_price = np.mean(prices)
print("Mean Price:", mean_price)

# Median price
median_price = np.median(prices)
print("Median Price:", median_price)

# Standard deviation
std_price = np.std(prices)
print("Standard Deviation:", std_price)

# Average sales per category
unique_categories = np.unique(categories)

for category in unique_categories:
    category_prices = prices[categories == category]
    print(category)
    print("Average:", np.mean(category_prices))
    print("Total:", np.sum(category_prices))
    print("Max:", np.max(category_prices))
    print("Min:", np.min(category_prices))
# Out:
# Mean Price: 374.842
# Median Price: 165.0
# Standard Deviation: 466.2739098813057
# Books
# Average: 26.126168224299064
# Total: 5591
# Max: 50
# Min: 5
# Clothing
# Average: 52.767195767195766
# Total: 9973
# Max: 100
# Min: 10
# Electronics
# Average: 1067.5537634408602
# Total: 198565
# Max: 1999
# Min: 102
# Home & Kitchen
# Average: 248.26696832579185
# Total: 54867
# Max: 499
# Min: 20
# Sports & Outdoors
# Average: 557.0842105263158
# Total: 105846
# Max: 1000
# Min: 71

# %% [markdown]
# ---
#
#
#
# ---
#
#
# # Primer on Pandas
#
# Pandas is a powerful and flexible open-source Python library that provides data structures and functions for efficient data manipulation and analysis. It's built on top of NumPy and is often used in conjunction with other libraries like matplotlib and scikit-learn.You will deep dive into Pandas in a later tutorial, but do some self-learning about Pandas first.

# %% [markdown]
# ## Study this code below, what is happening?

# %%
import pandas as pd

# Dataframe 1: Hawker Centers
hawker_data = {'hawker_center': ['Maxwell Food Centre', 'Lau Pa Sat', 'Old Airport Road Food Centre'],
               'location': ['Chinatown', 'Raffles Place', 'Geylang'],
               'rating': [4.5, 4.2, 4.7]}
hawker_df = pd.DataFrame(hawker_data)
print(hawker_df)
print("--------------------------------------------------------")

# Dataframe 2: Dishes
dish_data = {'dish': ['Chicken Rice', 'Laksa', 'Char Kway Teow'],
             'hawker_center': ['Maxwell Food Centre', 'Lau Pa Sat', 'Old Airport Road Food Centre'],
             'price': [3.5, 5.0, 4.0]}
dish_df = pd.DataFrame(dish_data)
print(dish_df)
print("--------------------------------------------------------")

# Merge the dataframes on 'hawker_center'
merged_df = pd.merge(hawker_df, dish_df, on='hawker_center') #how is this merged?

print("Merged Dataframe:")
print(merged_df)
# Out:
#                   hawker_center       location  rating
# 0           Maxwell Food Centre      Chinatown     4.5
# 1                    Lau Pa Sat  Raffles Place     4.2
# 2  Old Airport Road Food Centre        Geylang     4.7
# --------------------------------------------------------
#              dish                 hawker_center  price
# 0    Chicken Rice           Maxwell Food Centre    3.5
# 1           Laksa                    Lau Pa Sat    5.0
# 2  Char Kway Teow  Old Airport Road Food Centre    4.0
# --------------------------------------------------------
# Merged Dataframe:
#                   hawker_center       location  rating            dish  price
# 0           Maxwell Food Centre      Chinatown     4.5    Chicken Rice    3.5
# 1                    Lau Pa Sat  Raffles Place     4.2           Laksa    5.0
# 2  Old Airport Road Food Centre        Geylang     4.7  Char Kway Teow    4.0

# %% [markdown]
# ### The code creates two dataframes, hawker_df and dish_df, containing information about Singaporean hawker centers and dishes, respectively. It then merges these two dataframes into a single dataframe, merged_df, based on the common column 'hawker_center'. Finally, it prints the merged dataframe, showing information about hawker centers, their locations, ratings, and the dishes they offer along with their prices.
#
#
# ## Look at the different ways of data analytics that can be done in Pandas. Run, and understand them. You will have to apply them in the later cells.

# %%
# Get the number of rows and columns
num_rows, num_cols = merged_df.shape

# Display information about the DataFrame (data types, missing values, etc.)
merged_df.info()

# Display the first 10 rows of the DataFrame
merged_df.head(10)

# Display the last 5 rows of the DataFrame
merged_df.tail()

# Get a statistical summary of numerical columns (mean, std, min, max, etc.)
merged_df.describe()

# Access a specific column by name
prices = merged_df['price']

# Calculate the mean of the 'price' column
mean_price = merged_df['price'].mean()

# Find the maximum value in the 'rating' column
max_rating = merged_df['rating'].max()

# Count the occurrences of each unique value in the 'category' column
category_counts = merged_df['dish'].value_counts()

# Sort the DataFrame by the 'price' column in ascending order
sorted_by_price = merged_df.sort_values(by=['price'])

# Sort the DataFrame by the 'rating' column in descending order
sorted_by_rating = merged_df.sort_values(by=['rating'], ascending=False)

# Filter rows where the 'price' is greater than 10
filtered_df = merged_df[merged_df['price'] > 10]

# Create a new column 'price_per_rating' by dividing 'price' by 'rating'
merged_df['price_per_rating'] = merged_df['price'] / merged_df['rating']

# Group the DataFrame by 'category' and calculate the mean price for each category
category_mean_prices = merged_df.groupby('dish')['price'].mean()

# Apply a function to each element of the 'price' column (e.g., add 10)
merged_df['price'] = merged_df['price'].apply(lambda x: x + 10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   hawker_center  3 non-null      object
#  1   location       3 non-null      object
#  2   rating         3 non-null      float64
#  3   dish           3 non-null      object
#  4   price          3 non-null      float64
# dtypes: float64(2), object(3)
# memory usage: 252.0+ bytes

# %% [markdown]
# ## Your assignment for Pandas.
#
# ### Work with the Pandas dataset below and analyze the data, answering the questions through the methods learnt the previous cells:
#
# 1. What is the average price of Chilli Crab?
# 2. What is the distribution of ratings for each food item?
# 3. What is the highest price of the most expensive food?
# 4. What is the highest price of the lowest expensive food?

# %%
import pandas as pd

data = {
    'food': ['Hokkien Mee', 'Chicken Rice', 'Fish Head Curry', 'Roti Prata', 'Chilli Crab', 'Wanton Mee', 'Roti Prata', 'Chilli Crab', 'Laksa', 'Wanton Mee', 'Fish Head Curry', 'Hokkien Mee', 'Hokkien Mee', 'Bak Kut Teh', 'Chicken Rice'],
    'stall': ['Au Pa Sat', 'Ah Loy My', 'Au Pa Sat', 'Au Pa Sat', 'Au Pa Sat', 'Ah Loy My', 'Au Pa Sat', 'Axwell Food Centre', 'Axwell Food Centre', 'Axwell Food Centre', 'Axwell Food Centre', 'Ah Loy My', 'Ah Loy My', 'Axwell Food Centre', 'Axwell Food Centre'],
    'price': [8.5, 8.5, 7.5, 7.5, 8.5, 11.5, 6.5, 5.5, 4.5, 8.5, 5.5, 7.5, 5.5, 7.5, 6.5],
    'rating': [5, 2, 5, 1, 2, 3, 2, 2, 3, 1, 5, 5, 1, 3, 3]
}

sg_food_df = pd.DataFrame(data)
sg_food_df
# Out:
#                food               stall  price  rating
# 0       Hokkien Mee           Au Pa Sat    8.5       5
# 1      Chicken Rice           Ah Loy My    8.5       2
# 2   Fish Head Curry           Au Pa Sat    7.5       5
# 3        Roti Prata           Au Pa Sat    7.5       1
# 4       Chilli Crab           Au Pa Sat    8.5       2
# 5        Wanton Mee           Ah Loy My   11.5       3
# 6        Roti Prata           Au Pa Sat    6.5       2
# 7       Chilli Crab  Axwell Food Centre    5.5       2
# 8             Laksa  Axwell Food Centre    4.5       3
# 9        Wanton Mee  Axwell Food Centre    8.5       1
# 10  Fish Head Curry  Axwell Food Centre    5.5       5
# 11      Hokkien Mee           Ah Loy My    7.5       5
# 12      Hokkien Mee           Ah Loy My    5.5       1
# 13      Bak Kut Teh  Axwell Food Centre    7.5       3
# 14     Chicken Rice  Axwell Food Centre    6.5       3

# %% [markdown]
# ## Your analysis to answer these 4 questions:
#
# 1. What is the average price of Chilli Crab?
# 2. What is the distribution of ratings for each food item?
# 3. What is the highest price of the most expensive food?
# 4. What is the highest price of the lowest expensive food?

# %%
##Feel free to write as much code and explain in comments

# %% [markdown]
# ## Sample EST Questions

# %% [markdown]
# ### Question  1: Using NumPy methods, how would you combine the store_data_1 and store_data_2 into a new NumPy Array - combined_store_data?
#
# Your combined_store_data should look like:
#
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np

# Create two sample NumPy arrays representing store data
store_data_1 = np.array([
    [1, 'Clothing', 'Shoes', 99, '2007-2-28'],
    [2, 'Books', 'Magazine', 8, '2005-8-2']
])

store_data_2 = np.array([
    [3, 'Books', 'Novel', 21, '2002-4-16'],
    [4, 'Clothing', 'Shoes', 62, '2001-7-9']
])

# Write your code here
#------------------------
combined_store_data = np.concatenate((store_data_1, store_data_2))

#------------------------

# Print the combined array
print(combined_store_data)
# Out:
# [['1' 'Clothing' 'Shoes' '99' '2007-2-28']
#  ['2' 'Books' 'Magazine' '8' '2005-8-2']
#  ['3' 'Books' 'Novel' '21' '2002-4-16']
#  ['4' 'Clothing' 'Shoes' '62' '2001-7-9']]

# %% [markdown]
# ### Question 2:
# For the combined_store_data the columns in the numpy_array represent the following:
#
# - Column 0 (index): This column contains a unique identifier for each record in the data. It seems to be a simple sequential number.
# - Column 1 (category): This column represents the broad category of the item being sold (e.g., 'Clothing', 'Books', 'Home & Kitchen').
# - Column 2 (item): This column provides a more specific name for the item within its category (e.g., 'Shoes', 'Magazine', 'Cookware').
# - Column 3 (price): This column holds the price of the item.
# - Column 4 (date): This column contains the date when the item was sold. The dates are in a string format (e.g., 'YYYY-M-D' or 'YYYY-MM-DD').

# %%
combined_store_data = np.array([
    [1, 'Clothing', 'Shoes', '100', '2007-2-28'],
    [2, 'Books', 'Magazine', '8', '2005-8-2'],
    [3, 'Books', 'Novel', '21', '2002-4-16'],
    [4, 'Clothing', 'Shoes', '62', '2001-7-9']
                                ])

# %% [markdown]
# ## How can you analzye the average cost of shoes using the NumPy methods that you are learnt (follow the cheatsheet)?

# %%
#write your code here

# %% [markdown]
# ## Question 3
# Calculate the cumulative sales for each day of the week given the daily_sales array. In other words, find the total sales up to and including each day.
#
# Your output should be such:
#
# ![image.png](data:image/png;base64,...)

# %%
# This array represents the daily sales for a week
daily_sales = np.array([150, 200, 180, 220, 250, 300, 280])

#write your code here

# %% [markdown]
# ## Question 4
# Basic Signal Processing
#
# You are given a 1D array representing time-series data from multiple sensors:
# - The data contains some missing values (represented as NaN)
#
# Your task is to implement the following pipeline WITHOUT using explicit loops:
# Replace missing values (NaN) with mean of data using NumPy methods (refer only to the cheatsheet above)

# %%
data_array = [1, 2, np.NaN, 4, 5, 6, np.NaN, 8, 9, 10]
#write your code

# %% [markdown]
# # 👏Congratulations, you've finished the practical! Please make sure you've completed all the required work in this notebook. Submit your work on Brightspace.
#
# Further Study: 💻 https://app.datacamp.com/learn/courses/introduction-to-numpy

# %% [markdown]
# ## Annex: The code used the generate many different items for the NumPy

# %%
import numpy as np
import random

# Define categories, items, and price ranges
categories = ["Electronics", "Clothing", "Books", "Home & Kitchen", "Sports & Outdoors"]
items = {
    "Electronics": ["Laptop", "Smartphone", "Tablet", "Headphones", "Camera"],
    "Clothing": ["Shirt", "Pants", "Dress", "Shoes", "Jacket"],
    "Books": ["Novel", "Textbook", "Comic", "Magazine", "Biography"],
    "Home & Kitchen": ["Cookware", "Utensils", "Appliances", "Furniture", "Decor"],
    "Sports & Outdoors": ["Bicycle", "Tent", "Sleeping Bag", "Hiking Boots", "Fishing Rod"],
}
price_ranges = {
    "Electronics": (100, 2000),
    "Clothing": (10, 100),
    "Books": (5, 50),
    "Home & Kitchen": (20, 500),
    "Sports & Outdoors": (50, 1000),
}

# Generate 100 entries
data_entries = []
for i in range(1, 1001):
    category = random.choice(categories)
    item = random.choice(items[category])
    price = random.randint(price_ranges[category][0], price_ranges[category][1])
    date = f"200{random.randint(1, 9)}-{random.randint(1, 12)}-{random.randint(1, 30)}"  # Generate random dates in November
    entry = f"{i},{category},{item},{price},{date}"
    data_entries.append(entry)

# Join the entries into a single string
data_string = ";".join(data_entries)

# %%
data_string
# Out:
# '1,Clothing,Shoes,99,2007-2-28;2,Books,Magazine,8,2005-8-2;3,Books,Novel,21,2002-4-16;4,Clothing,Shoes,62,2001-7-9;5,Home & Kitchen,Cookware,107,2006-4-21;6,Sports & Outdoors,Fishing Rod,1000,2008-6-23;7,Electronics,Tablet,1219,2002-10-20;8,Home & Kitchen,Appliances,300,2002-4-8;9,Clothing,Jacket,88,2004-3-3;10,Clothing,Pants,79,2005-6-9;11,Clothing,Dress,12,2006-1-25;12,Sports & Outdoors,Bicycle,604,2005-6-27;13,Books,Magazine,26,2009-6-25;14,Home & Kitchen,Decor,319,2007-7-8;15,Books,Biography,44,2005-6-22;16,Sports & Outdoors,Hiking Boots,872,2002-4-19;17,Clothing,Shirt,45,2002-10-16;18,Books,Biography,19,2007-7-29;19,Home & Kitchen,Appliances,207,2002-7-8;20,Sports & Outdoors,Fishing Rod,766,2001-11-26;21,Home & Kitchen,Decor,340,2007-1-10;22,Home & Kitchen,Decor,482,2001-6-7;23,Home & Kitchen,Cookware,276,2004-11-5;24,Home & Kitchen,Cookware,215,2004-12-9;25,Books,Magazine,23,2007-10-22;26,Electronics,Smartphone,1791,2008-1-18;27,Clothing,Pants,86,2001-2-5;28,Home & Kitchen,Cook
# ...

# %% [markdown]
# This is the python code to generate random data for dataframes.

# %%
import pandas as pd
import numpy as np

# Generate some sample data with more variety
num_rows = 20  # Increase for more data points

# Define lists of food items, stalls, and prices for more variability
food_items = ['Chicken Rice', 'Laksa', 'Char Kway Teow', 'Nasi Lemak', 'Hokkien Mee', 'Satay', 'Roti Prata', 'Chilli Crab', 'Fish Head Curry', 'Bak Kut Teh', 'Wanton Mee']
stall_names = ['Ah Loy My', 'Axwell Food Centre', 'Au Pa Sat']
price_ranges = [3.5, 4.5, 5.5, 6.5, 7.5, 8.5, 9.5, 10.5, 11.5, 12.5]  # More price options

# Create DataFrame columns
food = np.random.choice(food_items, num_rows)
stall = np.random.choice(stall_names, num_rows)
price = np.random.choice(price_ranges, num_rows)
rating = np.random.randint(1, 6, num_rows)  # Rating from 1 to 5

# Create the DataFrame
sg_food_df = pd.DataFrame({'food': food, 'stall': stall, 'price': price, 'rating': rating})
sg_food_df  # Display the first few rows
# Out:
#                food               stall  price  rating
# 0       Hokkien Mee           Au Pa Sat    8.5       5
# 1      Chicken Rice           Ah Loy My    8.5       2
# 2   Fish Head Curry           Au Pa Sat    7.5       5
# 3        Roti Prata           Au Pa Sat    7.5       1
# 4       Chilli Crab           Au Pa Sat    8.5       2
# 5        Wanton Mee           Ah Loy My   11.5       3
# 6        Roti Prata           Au Pa Sat    6.5       2
# 7       Chilli Crab  Axwell Food Centre    5.5       2
# 8             Laksa  Axwell Food Centre    4.5       3
# 9        Wanton Mee  Axwell Food Centre    8.5       1
# 10  Fish Head Curry  Axwell Food Centre    5.5       5
# 11      Hokkien Mee           Ah Loy My    7.5       5
# 12      Hokkien Mee           Ah Loy My    5.5       1
# 13      Bak Kut Teh  Axwell Food Centre    7.5       3
# 14     Chicken Rice  Axwell Food Centre    6.5       3
# 15            Satay  Axwell Food Centre    7.5       1
# ...
