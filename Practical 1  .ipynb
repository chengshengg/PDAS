# %% [markdown]
# # Welcome to Programming for Data Analytics Practical 1 👏

# %% [markdown]
# 👆 Before proceeding, please navigate to the provided DataCamp link and complete the 3-hour practical exercise on Introduction to Python for Developers. This will provide you with a foundational understanding of Python, which is essential for the subsequent content in this notebook. Even though this DataCamp Course says it takes 3 hours, you are able to complete it with lesser as you have prior programming background.
#
# Please log in with your iChat account always for Datacamp!
#
# 💻 https://app.datacamp.com/learn/courses/introduction-to-python-for-developers

# %% [markdown]
# ## Submit your DataCamp Completion Certificate
#
# To verify your completion of the DataCamp practical exercise, please submit your certificate of completion below. You can do this by:
#
# 1. Taking a screenshot of your certificate.
# 2. Pasting the screenshot into the designated area below. (You can paste by double-clicking this text and pressing Ctrl+V or by right-clicking and selecting "Paste".)

# %% [markdown]
# ---
#
# Paste Your Certificate Here
# ![image.png](attachment:image.png)
#
# ---

# %% [markdown]
# ## You may only proceed to do the question(s) below only after you have copied and pasted your certificate.
#
# ## ⚠️ Please avoid using ChatGPT or GenAI for these questions. Independent work is crucial for your success on the end-of-semester test.
#
# ## Use the local Jupyter Notebook without GenAI tools for this practical.
#
# ### Below is a portion of the cheatsheet that will be given to you for your EST, the EST is a closed book exam and you can only refer to this cheatsheet, and use Jupyter Notebook.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Question 1:
#
# Write a program that takes an arbitrary number of numerical inputs from the user and determines the largest among them. The program should:
#
# 1. Prompt the user to enter the number of values they want to compare.
# 2. Use a loop to repeatedly ask the user for each numerical input.
# 3. Track and update the largest number encountered so far.
# 4. Print the largest number after all inputs have been processed.
# Important Considerations:
#
# - The program should handle both positive and negative numbers.
# - The program should not store all entered numbers in a list to save memory.
# - The program should utilize a while loop for iteration.
#
# You may only fill up the code in the "Write code here area".

# %%
num_count = int(input("How many numbers do you want to enter? "))
largest_number = 0  # Initialize with 0
count = 0
while count < num_count:
#Write code here===============================
    count += 1
    userinput = int(input("Enter a number: "))
    if userinput > largest_number:
        largest_number = userinput

###===========================================
print("The largest number is:", largest_number)
# Out:
# How many numbers do you want to enter?  3
# Enter a number:  1
# Enter a number:  2
# Enter a number:  3
# The largest number is: 3

# %% [markdown]
# ## Question 2:
# Calculate the cGPA (Cumulative Grade Point Average) based on the string scores that has been given to you.
#
# You are provided with the following variables:
#
# a. cGPA that starts as a variable 0.
#
# b. scores as a string that stores 4 different score: 4.0, 3.0, 5.0, 5.0.
#
# Hints:
# 1. Use str.split()
# 2. Should type cast be used?
#
# You may only fill up the code in the "Write code here area".

# %%
cGPA = 0
scores = "4.0 3.0 5.0 5.0"
#Do not edit the code above

#Write code here=========================

string_scores = scores.split(" ")
total = 0
count = 0
for score in string_scores:
    count += 1
    total += float(score)

cGPA = total/count
#===========================================
print(cGPA)
# Out:
# 4.25

# %% [markdown]
# # 👏Congratulations, you've finished Practical 1! Please make sure you've completed all the required work in this notebook. Submit your work on Brightspace.
