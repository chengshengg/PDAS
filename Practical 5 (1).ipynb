# %% [markdown]
# # Welcome to Programming for Data Analytics Practical 5 👏

# %% [markdown]
# 👆 Before proceeding, please navigate to the provided DataCamp link and complete the practical exercise on Introduction to Data Visualization with Matplotlib. This will provide you with a foundational understanding of Matplotlib, which is essential for the subsequent content in this notebook.
#
# Complete the last two topics of:
# https://app.datacamp.com/learn/courses/introduction-to-data-science-in-python
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Submit your DataCamp Completion Certificate
#
# To verify your completion of the DataCamp practical exercise, please submit your certificate of completion below. You can do this by:
#
# 1. Taking a screenshot of your certificate.
# 2. Pasting the screenshot into the designated area below. (You can paste by double-clicking the area and pressing Ctrl+V or by right-clicking and selecting "Paste".)

# %% [markdown]
# ---
#
# Paste Your Certificate Here
#
#
# ---

# %% [markdown]
# ## You may only proceed to do the question(s) below only after you have copied and pasted your certificate.
#
# ## ⚠️ Please avoid using ChatGPT or GenAI for these questions. Independent work is crucial for your success on the end-of-semester test.
#
# ## Use the local Jupyter Notebook without GenAI tools for this practical.
#
# ### Below is a portion of the cheatsheet that will be given to you for your EST, the EST is a closed book exam and you can only refer to this cheatsheet, and use Jupyter Notebook.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Question 1:
#
# ![image.png](data:image/png;base64,...)
#
# **Create this line chart based on the data given to you**

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Sleep data as a dictionary
sleep_data = {
    'Day': [1, 2, 3, 4, 5, 6, 7],
    'Hours_Slept': [7.5, 6.8, 8.1, 7.2, 7.8, 6.5, 8.5]
}

#Write your code below============================

#===================================

# %% [markdown]
# ### Question 2
#
# ![image.png](data:image/png;base64,...)![image.png]()

# %% [markdown]
# **Create this scatter plot based on the data given to you**

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Sleep data as a dictionary
sleep_data = {
    'Day': [1, 2, 3, 4, 5, 6, 7],
    'Hours_Slept': [7.5, 6.8, 8.1, 7.2, 7.8, 6.5, 8.5]
}

#Write your code below============================

#============================================

# %% [markdown]
# # Final Question you will be making a Sleep Tracking Analyzer App

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# This is your data called sleep_data with columns for 'Day', 'Deep Sleep (hours)', 'Light Sleep (hours)', 'REM Sleep (hours)', 'Awake Time (hours)', and 'Total Sleep (hours)'. You can use the sample data provided below, but it is important to understand how to replace it with your own sleep tracking data.

# %%
sleep_data = pd.DataFrame({
    'Day': ['Mon', 'Tue', 'Wedn', 'Thur', 'Fri', 'Sat', 'Sun'],
    'Deep Sleep (hours)': [2, 2.5, 1.8, 2.2, 2.7, 2, 0],
    'Light Sleep (hours)': [4, 3.5, 3.2, 3.8, 1.3, 1, 0],
    'REM Sleep (hours)': [1.5, 2.8, 1.2, 1.5, 1.7, 2, 1.5],
    'Awake Time (hours)': [0.5, 0.2, 0.8, 0.5, 0.3, 0, 0.5],
    'Total Sleep (hours)': [8, 9, 7, 8, 6, 5, 2]
})

# %% [markdown]
# Steps to create the dashboard:
# 1. Bar Chart: Create a bar chart showing the breakdown of sleep stages (Deep Sleep, Light Sleep, REM Sleep, Awake Time) for each day of the week.
# 2. Pie Chart: Create a pie chart to display the average distribution of sleep stages.
# 3. Histogram: Create a histogram to visualize the distribution of total sleep hours.
# 4. Scatter Plot: Create a scatter plot to show the relationship between deep sleep hours and total sleep hours. Add a best-fit line (linear regression) to the scatter plot.
# 5. Box Plot: Create a horizontal boxplot to visualize the distribution of total sleep hours.
# 6. Dashboard Layout: Arrange the charts in a 2x3 grid layout such that the bar chart and the pie chart are placed side by side on the first row, with the bar chart occupying the first column and the pie chart occupying the second column, while the histogram, scatter plot, and box plot are placed on the second row, with the histogram occupying the first column, scatter plot occupying the second column, and box plot occupying the third column.
#
# Provide the complete Python code (using only Matplotlib and Pandas) necessary to create this dashboard.

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

sleep_data = pd.DataFrame({
    'Day': ['Mon', 'Tue', 'Wedn', 'Thur', 'Fri', 'Sat', 'Sun'],
    'Deep Sleep (hours)': [2, 2.5, 1.8, 2.2, 2.7, 2, 0],
    'Light Sleep (hours)': [4, 3.5, 3.2, 3.8, 1.3, 1, 0],
    'REM Sleep (hours)': [1.5, 2.8, 1.2, 1.5, 1.7, 2, 1.5],
    'Awake Time (hours)': [0.5, 0.2, 0.8, 0.5, 0.3, 0, 0.5],
    'Total Sleep (hours)': [8, 9, 7, 8, 6, 5, 2]
})

# %% [markdown]
# ## Sample EST Questions

# %% [markdown]
# ## Question 1
#
# Complete the code to create the graph expected:
#
# ![image.png](attachment:image.png)

# %%
#write your code here

# %% [markdown]
# ## Question 2
#
# Given the data x,y1 and y2, create the graph below:
#
# ![image.png](attachment:image.png)

# %%
import matplotlib.pyplot as plt
import numpy as np
# Create sample data
x = np.linspace(0, 10, 100)
y1 = np.sin(x)
y2 = np.cos(x)
#write your code here

# %% [markdown]
# ## Question 3
# Write code to create the graph below:
#
# ![image.png](attachment:image.png)

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# # 👏Congratulations, you've finished the practical! Please make sure you've completed all the required work in this notebook. Submit your work on Brightspace.
#
# For more: 💻 https://app.datacamp.com/learn/courses/introduction-to-data-visualization-with-matplotlib
